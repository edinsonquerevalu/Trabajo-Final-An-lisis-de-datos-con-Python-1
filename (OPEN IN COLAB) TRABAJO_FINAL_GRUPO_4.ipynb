# %% [markdown]
# <a href="https://colab.research.google.com/github/edinsonquerevalu/Trabajo-Final-An-lisis-de-datos-con-Python-1/blob/main/(OPEN%20IN%20COLAB)%20TRABAJO_FINAL_GRUPO_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
""" Trabajo-Grupo4-Análisis de Datos """
#Instalación de los códigos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pylab import array
from matplotlib.pylab import subplots
#Primero definimos las listas
Nombres=[]
Apellidos=[]
DNI=[]
Celular=[]
Email=[]
Operadora=[]
clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
#Programa
def Iniciar_datos():
  global clientes_dicc
  global df
  decision=input('Si desea agregar un usuario nuevo escriba "agr", si desea actualizar los datos de un usuario escriba "act",\nsi desea filtrar datos escriba "flt", si desea agregar una nueva característica escriba "nc", para salir solo presione enter: ')
  #Primera opción AGREGAR DATOS
  if decision=='agr':
    import pandas as pd
    Nombres.append(input('Introduzca el nombre del usuario: '))
    Apellidos.append(input('Introduzca el primer apellido del usuario: '))
    DNI.append(input('Introduzca el DNI del usuario: '))
    Celular.append(input('Introduzca el celular del usuario: '))
    Email.append(input('Introduzca el email del usuario: '))
    Operadora.append(input('Introduzca la operadora del usuario: '))
    clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
    df=pd.DataFrame(clientes_dicc)
    print('Datos guardados correctamente')
    print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    Iniciar_datos()
  #Segunda opción ACTUALIZAR DATOS
  elif decision=='act':
    def Actualizar_datos():
      global pd
      global df
      display(df)
      indice_nombre=input('Ingrese el nombre de la persona que desea actualizar sus datos (posterior a esto si desea podra salir): ')
      posicion=(Nombres.index(indice_nombre))
      dec=input('Escriba que dato de la persona desea actualizar:Nombres,Apellidos,DNI,Celular,Email,Operadora\nPor favor escriba su respuesta tal como se muestra anteriormente, para salir presione enter ')
      if dec=='Nombres':
        nv_nombre=input('Escriba el nuevo nombre: ')
        Nombres[posicion]=nv_nombre
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      elif dec=='Apellidos':
        nv_apellido=input('Escriba el nuevo apellido: ')
        Apellidos[posicion]=nv_apellido
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      elif dec=='DNI':
        nv_dni=input('Escriba el nuevo DNI: ')
        DNI[posicion]=nv_dni
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      elif dec=='Celular':
        nv_cel=input('Escriba el nuevo celular: ')
        Celular[posicion]=nv_cel
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      elif dec=='Email':
        nv_email=input('Escriba el nuevo email: ')
        Email[posicion]=nv_email
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      elif dec=='Operadora':
        nv_oper=input('Escriba la nueva operadora: ')
        Operadora[posicion]=nv_oper
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Dato actualizado')
        Actualizar_datos()
      else:
        clientes_dicc={'Nombres':Nombres,'Apellidos':Apellidos,'DNI':DNI,'Celular':Celular,'Email':Email,'Operadora':Operadora}
        df=pd.DataFrame(clientes_dicc)
        print('Datos actualizados correctamente')
        print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
        Iniciar_datos()   
    Actualizar_datos()
  #Tercera opción
  elif decision=='nc':
    def Agregar_car():
      global pd
      global df
      display(df)
      nv_caracteristica=input('Introduzca el nombre de la nueva característica que desea añadir: ')
      df[nv_caracteristica]='vacio'
      display(df)
    Agregar_car()
    print('Característica agregada correctamente')
    print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    Iniciar_datos()
  #Cuarta opción
  elif decision=='flt':
    def filtrar_datos():
      decision=input('Escriba "ok" para filtrar datos, para salir presione enter: ')
      if decision=='ok':
        global pd
        global df
        display(df)
        lolo=input('Escriba el nombre que desea filtrar: ')
        df_f=df['Nombres']==lolo
        filt=df[df_f]
        print('Datos filtrados:')
        print(filt)
      else:
        print('Programa cerrado')
    filtrar_datos()
    print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
    Iniciar_datos()
  #N.A
  else:
    if Nombres !=[]:
      import pandas as pd
      print('Sesión cerrada')
    else:
      print('No hay datos existentes')
      print('Se cerrará el programa')
Iniciar_datos()
print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
def Estads_datos():
  decision=input('Escriba "ok" para mostrar el análisis estadístico de las operadoras, para salir presione enter: ')
  if decision=='ok':
    global plt
    global df
    global np
    plt.style.use('seaborn-white')
    Operadora_array=np.array(Operadora)
    plt.hist(Operadora_array,bins=4,alpha=0.5,histtype='bar',color='red',edgecolor='black')
    plt.show()
  else:
    print(':)')
Estads_datos()
#Fin
print('-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------')
print('Ultima actualización de datos:')
display(df)
# Out:
# Si desea agregar un usuario nuevo escriba "agr", si desea actualizar los datos de un usuario escriba "act",
# si desea filtrar datos escriba "flt", si desea agregar una nueva característica escriba "nc", para salir solo presione enter: agr
# Introduzca el nombre del usuario: joa
# Introduzca el primer apellido del usuario: portal
# Introduzca el DNI del usuario: 5465465
# Introduzca el celular del usuario: 654654
# Introduzca el email del usuario: joa@htm.com
# Introduzca la operadora del usuario: claro
# Datos guardados correctamente
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Si desea agregar un usuario nuevo escriba "agr", si desea actualizar los datos de un usuario escriba "act",
# si desea filtrar datos escriba "flt", si desea agregar una nueva característica escriba "nc", para salir solo presione enter: agr
# ...
